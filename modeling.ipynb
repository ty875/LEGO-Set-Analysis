# %%
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestClassifier
from statsmodels.tsa.arima.model import ARIMA
import pandas as pd

# %%
train_data = pd.read_csv('train_data.csv')
test_data = pd.read_csv('test_data.csv')
test_data.head()
# Out:
#    Year  Pieces    CPI Mean  Theme_4 Juniors  Theme_Action Wheelers  \
# 0  2019     6.0  391.299154            False                  False
# 1  2016   110.0  376.622000            False                  False
# 2  2023   305.0  436.901846            False                  False
# 3  1996    31.0  298.323077            False                  False
# 4  2012   110.0  366.702077            False                  False
#
#    Theme_Advanced models  Theme_Adventurers  Theme_Agents  Theme_Alpha Team  \
# 0                  False              False         False             False
# 1                  False              False         False             False
# 2                  False              False         False             False
# 3                  False              False         False             False
# 4                  False              False         False             False
#
#    Theme_Aqua Raiders  ...  Set name_{Racer}  Set name_{Rattlesnake}  \
# 0               False  ...             False                   False
# 1               False  ...             False                   False
# 2               False  ...             False                   False
# 3               False  ...             False                   False
# 4               False  ...             False                   False
#
#    Set name_{Salamander}  Set name_{Skull}  Set name_{Space Shuttle}  \
# 0                  False             False                     False
# 1                  False             False                     False
# 2                  False             False                     False
# 3                  False             False                     False
# 4                  False             False                     False
#
#    Set name_{Transport Plane}  Set name_{Wild Turkey}  Value new (USD)  \
# 0                       False                   False             4.64
# 1                       False                   False            38.12
# 2                       False                   False            29.88
# 3                       False                   False            38.12
# 4                       False                   False            38.12
#
#    RRP (USD)  Value used (USD)
# 0       39.9              3.87
# 1       49.9             20.00
# 2      349.9             16.00
# 3      220.0             20.00
# 4      299.9             20.00
#
# [5 rows x 11652 columns]

# %% [markdown]
# # Arima Model

# %%
for target in train_data[['Value new (USD)', 'RRP (USD)', 'Value used (USD)']]:
# Out:
# 1
# 1
# 1

# %% [markdown]
# # Linear Regression Model

# %% [markdown]
# # Random Forest Model
